# %%
import sys
import os

import cv2
from keras.models import load_model
import numpy as np

from utils.datasets import get_labels
from utils.inference import detect_faces
from utils.inference import draw_text
from utils.inference import draw_bounding_box
from utils.inference import apply_offsets
from utils.inference import load_detection_model
from utils.inference import load_image
from utils.preprocessor import preprocess_input

from keras.preprocessing import image

import cv2
import math
import numpy as np

import matplotlib
# %matplotlib inline
from matplotlib import pylab as plt
import matplotlib.patches as patches

from IPython.display import clear_output

import face_recognition
from scipy.interpolate import spline

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

import time
from tqdm import tqdm_notebook as tqdm
from os.path import join as pj
import json
# Out:
# Using TensorFlow backend.
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8194767159578497610
# , name: "/gpu:0"
# device_type: "GPU"
# memory_limit: 7958219981
# locality {
#   bus_id: 1
# }
# incarnation: 6564811094157515207
# physical_device_desc: "device: 0, name: GeForce GTX 1080, pci bus id: 0000:02:00.0"
# ]

# %%
image_path = sys.argv[1]
detection_model_path = '../trained_models/detection_models/haarcascade_frontalface_default.xml'
emotion_model_path = '../trained_models/emotion_models/fer2013_mini_XCEPTION.102-0.66.hdf5'
gender_model_path = '../trained_models/gender_models/simple_CNN.81-0.96.hdf5'
emotion_labels = get_labels('fer2013')
gender_labels = get_labels('imdb')
font = cv2.FONT_HERSHEY_SIMPLEX

# hyper-parameters for bounding boxes shape
gender_offsets = (30, 60)
gender_offsets = (10, 10)
emotion_offsets = (20, 40)
emotion_offsets = (0, 0)

# loading models
face_detection = load_detection_model(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
gender_classifier = load_model(gender_model_path, compile=False)

# getting input model shapes for inference
emotion_target_size = emotion_classifier.input_shape[1:3]
gender_target_size = gender_classifier.input_shape[1:3]

# %%
def detect_face(image, video_file_path, frame_id):
    to_save = np.random.rand() > 0.99
    if not to_save:
        image = cv2.resize(image, (0,0), fx=0.25, fy=0.25)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_image = np.squeeze(gray_image)
    gray_image = gray_image.astype('uint8')

    
    faces = detect_faces(face_detection, gray_image)
    if len(faces) == 0:
        return {}

    data = {}

    # emotion
    for face_coordinates in faces:
        x1, x2, y1, y2 = apply_offsets(face_coordinates, emotion_offsets)
        gray_face = gray_image[y1:y2, x1:x2]

        gray_face = cv2.resize(gray_face, (emotion_target_size))

        gray_face = preprocess_input(gray_face, True)
        gray_face = np.expand_dims(gray_face, 0)
        gray_face = np.expand_dims(gray_face, -1)
        emotion_label_arg = np.argmax(emotion_classifier.predict(gray_face))
        emotion_text = emotion_labels[emotion_label_arg]

        data['emotion'] = emotion_text
        data['n_faces'] = len(faces)
        if not to_save:
            break  # only one face

        # save some images
        if to_save:
            draw_bounding_box(face_coordinates, image, (0, 0, 255))
            draw_text(face_coordinates, image, emotion_text, (0, 0, 255), 0, -10, 1, 2)
    
    if to_save:
        name = os.path.basename(video_file_path)[:-4]
        if not os.path.exists('./pics/{}'.format(name)):
            os.mkdir('./pics/{}'.format(name))
        plt.imsave('./pics/{}/{}.png'.format(name, frame_id), cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

    return data

# %%
def get_result(video_file_path):
    cap = cv2.VideoCapture(video_file_path)
    frame_rate = cap.get(5)  # frame rate
    frame_counter = 0

    result = []
    while cap.isOpened():
        frame_id = cap.get(1)
        ret, frame = cap.read()
        if not ret:
            break

        if frame_id % math.floor(frame_rate) == 0:
            frame_counter += 1
            try:
                result.append(detect_face(frame, video_file_path, frame_id))
            except Exception as e:
                print('Failed on frame. Reason: {}', frame_id, e)
                result.append({})

#             if frame_counter > 1 * 60:
#                 break

    cap.release()
    
    return result

# %%
def get_filepath_by_idx():
    filepath_by_idx = {}

    ROOT = '/data/junction'
    for idx in range(1, 1000):
        filenames = []
        for root, dirs, files in os.walk('{}/{}'.format(ROOT, idx)):
            for file in files:
                filenames.append(pj(root, file))
        candidates = [filename for filename in filenames if os.path.splitext(filename)[1] in ['.avi', '.mkv']]
        if len(candidates) != 1:
#             print('! {} Shit candidates {} != 1'.format(idx, len(candidates)))
            for filename in filenames:
                print(filename)
        else:
            filepath_by_idx[idx] = candidates[0]
            
    return filepath_by_idx

# %%
filepath_by_idx = get_filepath_by_idx()

# %%
for i, video_file_path in tqdm(list(filepath_by_idx.items())[68:]):
    done_idxs = os.listdir('./results')
    name = '{}.json'.format(i)
    if name in done_idxs:
        print('{} is already done'.format(name))
        continue
    
    result = get_result(video_file_path)
    with open('./results/' + name, 'w') as fout:
        json.dump(result, fout)
# Out:
# A Jupyter Widget
# 71.json is already done
# 72.json is already done
# 73.json is already done
# 74.json is already done
# 75.json is already done
# 76.json is already done
# 77.json is already done
# 78.json is already done
# 79.json is already done
# 80.json is already done
# 81.json is already done
# 82.json is already done
# 83.json is already done
# 84.json is already done
# 85.json is already done
# 86.json is already done
# 87.json is already done
# 88.json is already done
# 89.json is already done
# 90.json is already done
# 91.json is already done
# 92.json is already done
# 93.json is already done
# 94.json is already done
# 95.json is already done
# 96.json is already done
# 97.json is already done
# 98.json is already done
# 100.json is already done
# 251.json is already done
# 252.json is already done
# 253.json is already done
# 254.json is already done

# %%
# !ls -l results/
# Out:
# total 5388
# -rwxrwxrwx 1 root root  58839 Nov 25 16:07 1.json
# -rwxrwxrwx 1 root root  42233 Nov 25 16:44 10.json
# -rw-r--r-- 1 root root  14554 Nov 26 04:27 100.json
# -rwxrwxrwx 1 root root  94210 Nov 25 16:47 11.json
# -rwxrwxrwx 1 root root  46907 Nov 25 16:49 12.json
# -rwxrwxrwx 1 root root  35385 Nov 25 16:50 13.json
# -rwxrwxrwx 1 root root  68706 Nov 25 16:53 14.json
# -rwxrwxrwx 1 root root  95774 Nov 25 16:57 15.json
# -rwxrwxrwx 1 root root  68404 Nov 25 16:59 16.json
# -rwxrwxrwx 1 root root  54830 Nov 25 17:01 17.json
# -rwxrwxrwx 1 root root  54583 Nov 25 17:02 18.json
# -rwxrwxrwx 1 root root  66682 Nov 25 17:07 19.json
# -rwxrwxrwx 1 root root  70107 Nov 25 16:11 2.json
# -rwxrwxrwx 1 root root  37063 Nov 25 17:08 20.json
# -rwxrwxrwx 1 root root  36611 Nov 25 17:10 21.json
# -rwxrwxrwx 1 root root  42044 Nov 25 17:12 22.json
# -rwxrwxrwx 1 root root  80454 Nov 25 17:14 23.json
# -rwxrwxrwx 1 root root  51616 Nov 25 17:18 24.json
# -rwxrwxrwx 1 root root  62630 Nov 25 17:20 25.json
# -rw-r--r-- 1 root root  41519 Nov 26 04:33 251.json
# -rw-r--r-- 1 root root  34819 Nov 26 04:34 252.json
# -rw-r--r-- 1 root root  37180 Nov 26 04:36 253.json
# -rw-r--r-- 1 root root  40631 Nov 26 04:39 254.json
# -rwxrwxrwx 1 root root  35955 Nov 25 17:22 26.json
# -rwxrwxrwx 1 root root  49753 Nov 25 17:23 27.json
# -rwxrwxrwx 1 root root  52319 Nov 25 17:25 28.json
# -rwxrwxrwx 1 root root  34083 Nov 25 17:28 29.json
# -rwxrwxrwx 1 root root  61901 Nov 25 16:16 3.json
# -rwxrwxrwx 1 root root  48259 Nov 25 17:30 30.json
# -rwxrwxrwx 1 root root  57485 Nov 25 17:32 31.json
# -rwxrwxrwx 1 root root  67434 Nov 25 17:38 32.json
# -rwxrwxrwx 1 root root  99973 Nov 25 17:40 33.json
# -rwxrwxrwx 1 root root  79170 Nov 25 17:45 34.json
# -rwxrwxrwx 1 root root  60592 Nov 25 17:48 35.json
# -rwxrwxrwx 1 root root  33275 Nov 25 17:50 36.json
# -rwxrwxrwx 1 root root  43747 Nov 25 17:51 37.json
# -rwxrwxrwx 1 root root  28212 Nov 25 17:53 38.json
# -rwxrwxrwx 1 root root  31266 Nov 25 17:54 39.json
# -rwxrwxrwx 1 root root  50953 Nov 25 16:22 4.json
# -rwxrwxrwx 1 root root  45363 Nov 25 17:56 40.json
# -rwxrwxrwx 1 root root  68913 Nov 25 17:58 41.json
# -rwxrwxrwx 1 root root  49638 Nov 25 17:59 43.json
# -rwxrwxrwx 1 root root  39639 Nov 25 18:01 44.json
# -rwxrwxrwx 1 root root  43193 Nov 25 18:03 45.json
# -rwxrwxrwx 1 root root  58784 Nov 25 18:04 46.json
# -rwxrwxrwx 1 root root  59284 Nov 25 18:06 47.json
# -rwxrwxrwx 1 root root  22270 Nov 25 18:08 48.json
# -rwxrwxrwx 1 root root  46118 Nov 25 18:10 49.json
# -rwxrwxrwx 1 root root  66796 Nov 25 16:27 5.json
# -rwxrwxrwx 1 root root  56743 Nov 25 18:13 50.json
# -rwxrwxrwx 1 root root  32674 Nov 25 22:16 51.json
# -rwxrwxrwx 1 root root  49966 Nov 25 22:18 52.json
# -rwxrwxrwx 1 root root  48749 Nov 25 22:20 53.json
# -rwxrwxrwx 1 root root  32896 Nov 25 22:22 54.json
# -rwxrwxrwx 1 root root  49251 Nov 25 22:24 55.json
# -rwxrwxrwx 1 root root  53568 Nov 25 22:38 56.json
# -rwxrwxrwx 1 root root  23892 Nov 25 22:39 57.json
# -rwxrwxrwx 1 root root  33237 Nov 25 22:43 58.json
# -rwxrwxrwx 1 root root  47200 Nov 25 22:47 59.json
# -rwxrwxrwx 1 root root  59099 Nov 25 16:33 6.json
# -rwxrwxrwx 1 root root  60021 Nov 25 22:50 60.json
# -rwxrwxrwx 1 root root  25867 Nov 25 22:53 61.json
# -rwxrwxrwx 1 root root  52253 Nov 25 22:56 63.json
# -rwxrwxrwx 1 root root  50427 Nov 25 23:04 64.json
# -rwxrwxrwx 1 root root  35970 Nov 25 23:09 65.json
# -rwxrwxrwx 1 root root  46761 Nov 25 23:16 66.json
# -rwxrwxrwx 1 root root  55143 Nov 25 23:23 67.json
# -rwxrwxrwx 1 root root  45423 Nov 26 00:01 68.json
# -rwxrwxrwx 1 root root 115758 Nov 26 00:10 69.json
# -rwxrwxrwx 1 root root  60447 Nov 25 16:37 7.json
# -rwxrwxrwx 1 root root  71719 Nov 26 00:17 70.json
# -rwxrwxrwx 1 root root  73681 Nov 26 00:28 71.json
# -rwxrwxrwx 1 root root  46382 Nov 26 00:34 72.json
# -rwxrwxrwx 1 root root  82704 Nov 26 00:49 73.json
# -rwxrwxrwx 1 root root  64349 Nov 26 00:55 74.json
# -rw-r--r-- 1 root root  43287 Nov 26 01:03 75.json
# -rw-r--r-- 1 root root  81951 Nov 26 01:13 76.json
# -rw-r--r-- 1 root root  33720 Nov 26 01:22 77.json
# -rw-r--r-- 1 root root  30844 Nov 26 01:31 78.json
# -rw-r--r-- 1 root root  44618 Nov 26 01:40 79.json
# -rwxrwxrwx 1 root root  92865 Nov 25 16:40 8.json
# -rw-r--r-- 1 root root  58432 Nov 26 01:54 80.json
# -rw-r--r-- 1 root root  84701 Nov 26 02:08 81.json
# -rw-r--r-- 1 root root  29203 Nov 26 02:19 82.json
# -rw-r--r-- 1 root root  49775 Nov 26 02:29 83.json
# -rw-r--r-- 1 root root  60558 Nov 26 02:41 84.json
# -rw-r--r-- 1 root root  42841 Nov 26 02:50 85.json
# -rw-r--r-- 1 root root  65623 Nov 26 02:57 86.json
# -rw-r--r-- 1 root root  37479 Nov 26 03:04 87.json
# -rw-r--r-- 1 root root  50709 Nov 26 03:10 88.json
# -rw-r--r-- 1 root root  42830 Nov 26 03:15 89.json
# -rwxrwxrwx 1 root root  58485 Nov 25 16:42 9.json
# -rw-r--r-- 1 root root  35523 Nov 26 03:22 90.json
# -rw-r--r-- 1 root root  44144 Nov 26 03:30 91.json
# -rw-r--r-- 1 root root  35286 Nov 26 04:09 92.json
# -rw-r--r-- 1 root root  20669 Nov 26 04:10 93.json
# -rw-r--r-- 1 root root 130563 Nov 26 04:17 94.json
# -rw-r--r-- 1 root root  50957 Nov 26 04:19 95.json
# -rw-r--r-- 1 root root  28661 Nov 26 04:22 96.json
# -rw-r--r-- 1 root root  57745 Nov 26 04:24 97.json
# -rw-r--r-- 1 root root  34381 Nov 26 04:26 98.json

# %%
# !rm -rf results/*
