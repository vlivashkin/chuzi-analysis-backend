# %%
import pandas as pd

# %%
df = pd.read_csv('gunshots.csv')

# %%
a = []
for idx, row in df.iterrows():
    a.append({'id': row['id'], 'gunshots': row['gunshots'] + 10})

# %%
a
# Out:
# [{'gunshots': 17.0, 'id': 1.0},
#  {'gunshots': 76.0, 'id': 2.0},
#  {'gunshots': 77.0, 'id': 3.0},
#  {'gunshots': 186.0, 'id': 4.0},
#  {'gunshots': 10.0, 'id': 5.0},
#  {'gunshots': 13.0, 'id': 6.0},
#  {'gunshots': 37.0, 'id': 7.0},
#  {'gunshots': 13.0, 'id': 8.0},
#  {'gunshots': 12.0, 'id': 9.0},
#  {'gunshots': 43.0, 'id': 10.0},
#  {'gunshots': 12.0, 'id': 11.0},
#  {'gunshots': 10.0, 'id': 12.0},
#  {'gunshots': 135.0, 'id': 13.0},
#  {'gunshots': 57.0, 'id': 14.0},
#  {'gunshots': 11.0, 'id': 15.0},
#  {'gunshots': 13.0, 'id': 16.0},
#  {'gunshots': 99.0, 'id': 17.0},
#  {'gunshots': 233.0, 'id': 18.0},
#  {'gunshots': 12.0, 'id': 19.0},
#  {'gunshots': 156.0, 'id': 20.0},
#  {'gunshots': 43.0, 'id': 21.0},
#  {'gunshots': 22.0, 'id': 22.0},
#  {'gunshots': 13.0, 'id': 23.0},
#  {'gunshots': 13.0, 'id': 24.0},
#  {'gunshots': 14.0, 'id': 25.0},
#  {'gunshots': 13.0, 'id': 26.0},
#  {'gunshots': 51.0, 'id': 27.0},
#  {'gunshots': 14.0, 'id': 28.0},
# ...
